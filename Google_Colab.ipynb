# %% [markdown]
# <a href="https://colab.research.google.com/github/ttphong68/ttp-demo/blob/main/Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Giới thiệu và hướng dẫn sử dụng google colab
# ###1. Google Colab là gì?
# Google Colaboratory (Google Colab) là môi trường lập trình Python trực tuyến do Google Colab cung cấp.
# **Ưu điểm**
#
# ✅ Miễn phí
# ✅ Không cần cài Python
# ✅ Không cần cài Jupyter Notebook
# ✅ Tự động lưu trên Google Drive
# ✅ Hỗ trợ GPU và TPU
# ✅ Phù hợp cho:
#
# Data Analyst
# Data Scientist
# Machine Learning Engineer
# Deep Leaning & AI
# ###2. Tại sao Data Analyst nên dùng Google Colab?
# Muốn học Python cần:
# Cài Python
# Cài Jupyter
# Cài Pandas
# Cài NumPy
# Cấu hình môi trường, Rất dễ phát sinh lỗi.
#
# Với Google Colab, Chỉ cần:
# Có tài khoản Google
# Mở trình duyệt
# Truy cập Colab, Là có thể viết code ngay.
# ###3. Tạo Notebook đầu tiên
# Chạy Google colab https://colab.research.google.com/
# ![Colab_01.png](data:image/png;base64,...)
#
# - Examples : Ví dụ và hướng dẫn mẫu của Google colab
# - Recent : Những file Notebooks được mở gần đây, chỉ cần click và là có thể mở lại
# - Google drive : Những file Notebooks được lưu trên Google drive
# - GitHub : Những file Notebooks được lưu trên GitHub
# - Upload : Bạn có thể Upload file lên môi trường của Google colab nhấn nứt Browse
#
# **New notebook** để tạo một Notebook mới --> Hệ thống tạo ra tên file Untitled0.ipynb --> click vào đó để đổi tên file lại. Mặc định file Notebook có phần mở rộng là .ipynb
# ###4. Giao diện Google Colab
# Thanh Menu
# File  Edit View Insert Runtime Tools Help
# Cell
# Google Colab hoạt động theo Cell. Có 2 loại:
# Code Cell : Dùng để chạy mã Python, ví dụ print("Hello Data Analyst")
# Text Cell : Dùng để ghi chú bằng Markdown, ví dụ: # Doanh thu năm 2026
#
# Trước hết click vào nút **Connect** ở góc phải phía trên để khởi động môi trường của Colab
# ###5. Các phím tắt quan trọng
# | Phím          | Chức năng          |
# | ------------- | ------------------ |
# | Shift + Enter | Chạy Cell          |
# | Ctrl + M B    | Thêm Cell bên dưới |
# | Ctrl + M D    | Xóa Cell           |
# | Ctrl + S      | Lưu Notebook       |
#
# Để xem bảng lệnh click nút Commands phía trên bên trái
# Nút Run all để chạy tất cả các cell trong notebooks
# ###6. Upload file dữ liệu
# Nguồn dữ liệu có thể đưa vào Google Colab
# - Public Link :  Dữ liệu công khai các đường link trên internet
# - Google drive : Dữ liệu trên Google drive
# - Github Link : Dữ liệu trên tài khoản Github
# - Local Drive file : Dữ liệu trên ổ đĩa máy tính

# %% [markdown]
# ## Public Link
#
# https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv

# %%
# !wget https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv

# %%
# !ls

# %%
# Click vào nút 1 sẽ thấy file titanic.csv được tải về và lệnh !ls cũng liệt kê file này đang năm trong thư mục hiện hành

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Google drive

# %%
# Ánh xạ ổ đĩa Google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# !ls /content/drive/MyDrive/Python_for_data_analytics_062026

# %% [markdown]
# ##Github Link

# %%
# Đùng để kéo các repositories trên Github về Google Colab
# !git clone https://github.com/ttphong68/ttp-demo.git

# %% [markdown]
# ##Local Drive file
# - Click và nút mũi tên lên upload to session storage --> Chọn file cần upload --> Click nút Open ( Tương tự nút Upload ở bước 3. Tạo Notebook đầu tiên )
# - File tải lên chỉ tạm thời, khi hết phiên làm việc sẽ mất

# %% [markdown]
# ###7. Sơ lược về Text Cell và  Markdown

# %% [markdown]
# # This *is* **Heading**

# %% [markdown]
# ```
# # This is formatted as code
# print("Hello Google Colab")
# ```

# %% [markdown]
# [Tìm kiếm với google](https://www.google.com)

# %% [markdown]
# ![Cat.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Thụt lề
#
# > Add blockquote

# %% [markdown]
# 1.   Dòng thứ nhất
# 2.   Dòng thứ hai
# 3.   Dòng thứ ba

# %% [markdown]
# *   List item
# *   List item

# %% [markdown]
# $$ ax^2 + bx + c = 0 $$
#
# $ x1 = \frac{-b + \sqrt(b^2 - 4ac)}{2a} $

# %% [markdown]
# ###8. Cách lưu, tải xuống và chia sẻ tệp Colab

# %% [markdown]
# *   Để lưu thành một bản sao Notebook mới Click File --> Save a copy in Drive. Nó sẽ copy thành một file Notebook mới mang tên Copy of............ Nằm trong thư mục My Drive/Colab Notebooks/
# *   Để lưu thành một bản sao Notebook trên Github Click File --> Save a copy as a Github Gist
# *   List item
# *   List item
